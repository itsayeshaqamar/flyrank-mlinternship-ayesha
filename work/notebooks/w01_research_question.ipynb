# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/itsayeshaqamar/flyrank-mlinternship-ayesha/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### My Lane
#
# I selected **Lane 2: Refresh / Content Opportunity Scoring**
#
#
#  because it focuses on identifying webpages that should be reviewed first based on their search performance. I chose this lane because it addresses a practical SEO problem where content teams need to decide which pages deserve attention first. Instead of relying only on manually written rules, this project will explore whether machine learning can use observable signals such as impressions, CTR, content age, and average position to provide better recommendations while keeping the results easy to understand.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Decision
# The decision is to identify which webpages should be prioritized for content refresh based on their search performance and content signals.
#
# ### Action
# The SEO or content team will use the ranked recommendations to decide which pages should be updated, improved, or monitored first.
#
# ### Cost of a Wrong Recommendation
# If an important page is not recommended for refresh, it may continue to lose traffic and visibility. If a page that does not need attention is recommended instead, time and resources may be spent unnecessarily. The goal is to help prioritize review efforts more effectively rather than replace human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("content_refresh_anonymized.csv")

# 1. Dataset size
print(f"Dataset Shape: {df.shape[0]} rows and {df.shape[1]} columns")

# 2. Correlation between search volume and impressions
corr = df["search_volume"].corr(df["impressions_90d"])
print(f"Correlation between Search Volume and Impressions: {corr:.3f}")

# 3. Median word count by trend direction
print("\nMedian Word Count by Trend Direction:")
print(df.groupby("trend_direction")["word_count"].median().round(0))
# Out:
# Dataset Shape: 30000 rows and 44 columns
# Correlation between Search Volume and Impressions: 0.001
#
# Median Word Count by Trend Direction:
# trend_direction
# down      2909.0
# flat      2698.0
# new       2239.0
# stable    2912.0
# up        2848.0
# Name: word_count, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What this work can say:**
#
# This project can identify observed patterns and relationships between content signals and search performance metrics. It can provide directional insights about which pages may deserve review first based on available signals such as impressions, CTR, content age, and average position.
#
# The model can act as a decision-support tool by ranking pages according to their potential refresh opportunity. It can help SEO and content teams prioritize investigation and allocate resources more efficiently.
#
# **What this work cannot say:**
#
# This project cannot prove that a specific content factor directly causes ranking or traffic changes. The results show associations in the available data, not causal relationships.
#
# The model will not predict Google rankings, Google algorithm updates, or guarantee future traffic improvements. It cannot replace human SEO judgment or confirm that refreshing a specific page will definitely improve performance.
#
# The output should be treated as a prioritization recommendation and starting point for further review, not as a final decision or guaranteed outcome.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
