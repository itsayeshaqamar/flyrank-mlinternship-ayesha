# %% [markdown]
# <a href="https://colab.research.google.com/github/itsayeshaqamar/flyrank-mlinternship-ayesha/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/itsayeshaqamar/flyrank-mlinternship-ayesha/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Task Type: Ranking / Scoring
#
# My lane is a ranking/scoring problem because the goal is to prioritize which content pages should be refreshed first. Instead of predicting a simple yes/no outcome, the model assigns a priority score to each page based on signals such as content performance, freshness, and other available features. This ranking helps editors decide which pages to update first so they can focus their time on the content that is most likely to benefit from a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
task_type = "Ranking / Scoring"

print("ML Task Type:", task_type)
# Out:
# ML Task Type: Ranking / Scoring

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target: Refresh Priority Score
#
# The target is a refresh priority score for each content page. Since the starter dataset does not contain a direct label indicating which pages should be refreshed, this would be treated as a proxy target. The score can be estimated using observed signals such as changes in search performance, content freshness, and other available features. This provides a practical way to prioritize content for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
target = "Refresh Priority Score (Proxy)"

print("Target:", target)
# Out:
# Target: Refresh Priority Score (Proxy)

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ### Success Metric: Precision@K
#
# Since this is a ranking/scoring task, I would evaluate the model using Precision@K. A good model should rank the pages that most need refreshing near the top of the list so editors can focus on the highest-priority content first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
metric = "Precision@K"

print("Success Metric:", metric)
# Out:
# Success Metric: Precision@K

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ### Unit of Analysis
#
# One row represents one content page together with its associated features. Each row contains information such as content performance, freshness, and other available signals that can be used to estimate the page's refresh priority.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nFirst Five Rows:")
df.head()
# Out:
# Dataset Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# First Five Rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ### Why ML Beats a Fixed Rule
#
# A fixed rule, such as refreshing every page after a certain number of months, cannot consider all the factors that influence content quality and performance. Different pages may perform differently depending on user engagement, search trends, and freshness. Machine learning can combine multiple signals and identify complex patterns to produce a more accurate priority ranking. The model provides decision-support for editors rather than replacing their judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
fixed_rule = "Refresh every page after 6 months"
ml_approach = "Rank pages using multiple performance signals"

print("Example Fixed Rule:")
print(fixed_rule)

print("\nML Approach:")
print(ml_approach)
# Out:
# Example Fixed Rule:
# Refresh every page after 6 months
#
# ML Approach:
# Rank pages using multiple performance signals

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
